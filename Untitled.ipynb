# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
covid19 = pd.read_csv('owid-covid-data.csv')

# %%
covid19
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 0          ABW          Aruba  2020-03-13            2          2
# 1          ABW          Aruba  2020-03-20            4          2
# 2          ABW          Aruba  2020-03-24           12          8
# 3          ABW          Aruba  2020-03-25           17          5
# 4          ABW          Aruba  2020-03-26           19          2
# ...        ...            ...         ...          ...        ...
# 15960      NaN  International  2020-02-28          705          0
# 15961      NaN  International  2020-02-29          705          0
# 15962      NaN  International  2020-03-01          705          0
# 15963      NaN  International  2020-03-02          705          0
# 15964      NaN  International  2020-03-10          696         -9
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 0                 0           0                   18.733
# ...

# %%
covid19_latest = covid19[covid19['date']=="2020-05-08"]

# %%
covid19_latest
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 46         ABW         Aruba  2020-05-08          101          0
# 166        AFG   Afghanistan  2020-05-08         3563        171
# 214        AGO        Angola  2020-05-08           36          0
# 257        AIA      Anguilla  2020-05-08            3          0
# 318        ALB       Albania  2020-05-08          842         10
# ...        ...           ...         ...          ...        ...
# 15595      YEM         Yemen  2020-05-08           26          1
# 15669      ZAF  South Africa  2020-05-08         8232        424
# 15720      ZMB        Zambia  2020-05-08          153          7
# 15770      ZWE      Zimbabwe  2020-05-08           34          0
# 15900      NaN         World  2020-05-08      3807852      94158
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 46                3           1                  945.994
# 166             106           2                   91.527
# ...

# %%
covid19_latest = covid19_latest.drop(['total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','total_tests','new_tests','total_tests_per_thousand','new_tests_per_thousand','tests_units'],axis = 1)

# %%
covid19_latest.shape
# Out:
# (209, 7)

# %%
covid19_latest = covid19_latest.drop(['iso_code'],axis = 1)

# %%
covid19_latest.tail()
# Out:
#            location        date  total_cases  new_cases  total_deaths  \
# 15595         Yemen  2020-05-08           26          1             6
# 15669  South Africa  2020-05-08         8232        424           161
# 15720        Zambia  2020-05-08          153          7             4
# 15770      Zimbabwe  2020-05-08           34          0             4
# 15900         World  2020-05-08      3807852      94158        269068
#
#        new_deaths
# 15595           1
# 15669           8
# 15720           0
# 15770           0
# 15900        5780

# %%
covid19_latest = covid19_latest.drop([15900])

# %%
covid19_latest =covid19_latest.sort_values(by=['new_deaths'],ascending = False )
plt.figure(figsize = (12,8), dpi =80)
plt.bar(covid19_latest['location'][:12],covid19_latest['new_deaths'][:12],align='center',color='red')
plt.ylabel('Number of Deaths today',size=12)
plt.title('Country with Maximum deaths Latest', size =16)
plt.show()

# %% [markdown]
# Now we make anlisatiation of individual 12 countries of in graph from thie frist case

# %%
covid19_USA =covid19[covid19['location']=='United States']
covid19_USA.reset_index(inplace=True)
covid19_USA.tail()
covid19_USA = covid19_USA.drop(['index','iso_code','total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','total_tests','new_tests','total_tests_per_thousand','new_tests_per_thousand','tests_units'],axis =1)
covid19_USA.reset_index(inplace = True)
covid19_USA
covid19_USA.columns = ['Day Count', 'Country', 'Date', 'Total Case', 'New Case', 'Deaths', 'New Deaths' ]
covid19_USA
# Out:
#      Day Count        Country        Date  Total Case  New Case  Deaths  \
# 0            0  United States  2019-12-31           0         0       0
# 1            1  United States  2020-01-01           0         0       0
# 2            2  United States  2020-01-02           0         0       0
# 3            3  United States  2020-01-03           0         0       0
# 4            4  United States  2020-01-04           0         0       0
# ..         ...            ...         ...         ...       ...     ...
# 125        125  United States  2020-05-04     1158041     24972   67682
# 126        126  United States  2020-05-05     1180634     22593   68934
# 127        127  United States  2020-05-06     1204475     23841   71078
# 128        128  United States  2020-05-07     1228603     24128   73431
# 129        129  United States  2020-05-08     1256972     28369   75670
#
#      New Deaths
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
covid19_India = covid19[covid19['location']=='India']
covid19_India.reset_index(inplace = True)
covid19_India
covid19_India = covid19_India.drop(['index','iso_code','total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','total_tests','new_tests','total_tests_per_thousand','new_tests_per_thousand','tests_units'],axis =1)
covid19_India.reset_index(inplace = True)
covid19_India
covid19_India.columns = ['Day Count', 'Country', 'Date', 'Total Case', 'New Case', 'Deaths', 'New Deaths']
covid19_India
# Out:
#      Day Count Country        Date  Total Case  New Case  Deaths  New Deaths
# 0            0   India  2019-12-31           0         0       0           0
# 1            1   India  2020-01-01           0         0       0           0
# 2            2   India  2020-01-02           0         0       0           0
# 3            3   India  2020-01-03           0         0       0           0
# 4            4   India  2020-01-04           0         0       0           0
# ..         ...     ...         ...         ...       ...     ...         ...
# 124        124   India  2020-05-04       42533      2553    1373          72
# 125        125   India  2020-05-05       46433      3900    1568         195
# 126        126   India  2020-05-06       49391      2958    1694         126
# 127        127   India  2020-05-07       52952      3561    1783          89
# 128        128   India  2020-05-08       56342      3390    1886         103
#
# [129 rows x 7 columns]

# %%
covid19_Brazil = covid19[covid19['location']=='Brazil']
covid19_Brazil.reset_index(inplace = True)
covid19_Brazil
covid19_Brazil = covid19_Brazil.drop(['index','iso_code','total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','total_tests','new_tests','total_tests_per_thousand','new_tests_per_thousand','tests_units'],axis =1)
covid19_Brazil.reset_index(inplace = True)
covid19_Brazil
covid19_Brazil.columns = ['Day Count', 'Country', 'Date', 'Total Case', 'New Case', 'Deaths', 'New Deaths']
covid19_Brazil
# Out:
#      Day Count Country        Date  Total Case  New Case  Deaths  New Deaths
# 0            0  Brazil  2019-12-31           0         0       0           0
# 1            1  Brazil  2020-01-01           0         0       0           0
# 2            2  Brazil  2020-01-02           0         0       0           0
# 3            3  Brazil  2020-01-03           0         0       0           0
# 4            4  Brazil  2020-01-04           0         0       0           0
# ..         ...     ...         ...         ...       ...     ...         ...
# 125        125  Brazil  2020-05-04      101147      4588    7025         275
# 126        126  Brazil  2020-05-05      107780      6633    7321         296
# 127        127  Brazil  2020-05-06      114715      6935    7921         600
# 128        128  Brazil  2020-05-07      125218     10503    8536         615
# 129        129  Brazil  2020-05-08      135106      9888    9146         610
#
# [130 rows x 7 columns]

# %%
covid19_United_Kingdom = covid19[covid19['location']=='United Kingdom']
covid19_United_Kingdom.reset_index(inplace = True)
covid19_United_Kingdom
covid19_United_Kingdom = covid19_United_Kingdom.drop(['index','iso_code','total_cases_per_million','new_cases_per_million','total_deaths_per_million','new_deaths_per_million','total_tests','new_tests','total_tests_per_thousand','new_tests_per_thousand','tests_units'],axis =1)
covid19_United_Kingdom.reset_index(inplace = True)
covid19_United_Kingdom
covid19_United_Kingdom.columns = ['Day Count', 'Country', 'Date', 'Total Case', 'New Case', 'Deaths', 'New Deaths']
covid19_United_Kingdom
# Out:
#      Day Count         Country        Date  Total Case  New Case  Deaths  \
# 0            0  United Kingdom  2019-12-31           0         0       0
# 1            1  United Kingdom  2020-01-01           0         0       0
# 2            2  United Kingdom  2020-01-02           0         0       0
# 3            3  United Kingdom  2020-01-03           0         0       0
# 4            4  United Kingdom  2020-01-04           0         0       0
# ..         ...             ...         ...         ...       ...     ...
# 125        125  United Kingdom  2020-05-04      186599      4339   28446
# 126        126  United Kingdom  2020-05-05      190584      3985   28734
# 127        127  United Kingdom  2020-05-06      194990      4406   29427
# 128        128  United Kingdom  2020-05-07      201201      6211   30076
# 129        129  United Kingdom  2020-05-08      206715      5514   30615
#
#      New Deaths
# 0             0
# 1             0
# 2             0
# 3             0
# ...

# %%
plt.figure(figsize=(12,8),dpi=80)
plt.plot(covid19_USA['Day Count'], covid19_USA['New Case'])
plt.plot(covid19_India['Day Count'], covid19_India['New Case'])
plt.plot(covid19_Brazil['Day Count'], covid19_Brazil['New Case'])
plt.plot(covid19_United_Kingdom['Day Count'], covid19_United_Kingdom['New Case'])
plt.legend(['United States','India','Brazil','United_Kingdom'])
plt.xlabel('Day count', size=12)
plt.ylabel('New Cases', size=12)
plt.title('Which Country have Flatting curve?', size = 16)
plt.show()
